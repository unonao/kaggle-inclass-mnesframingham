# %%
#ColaboratoryかKaggleNotebookか判別
import sys
import os
from pathlib import Path

if 'google.colab' in sys.modules:  # colab環境
    INPUT = Path('/content/input/')

    # drive mount
    from google.colab import drive
    drive.mount('/content/drive/')

    # working dir に移動
    os.chdir('/content/drive/MyDrive/git/kaggle-inclass-mnesframingham')
    print("cwd:", os.getcwd())

    
elif 'kaggle_web_client' in sys.modules:  # kaggle環境
    INPUT = Path('../input/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# cwd: /content/drive/MyDrive/git/kaggle-inclass-mnesframingham

# %%
# !python run.py --config ./configs/nn000.json
# Out:
# 2021-04-04 13:04:16,075: config: ./configs/nn000.json
# 2021-04-04 13:04:16,076: ['original', 'pca', 'age_sysbp', 'female08_sysbp', 'female085_age']
# 2021-04-04 13:04:16,076: {'metric': 'auc_mu', 'seed': 41, 'num_threads': 7, 'num_class': 2}
# 2021-04-04 13:04:16,148: X_train_all shape: (3180, 20)
# Traceback (most recent call last):
#   File "run.py", line 150, in <module>
#     main()
#   File "run.py", line 146, in main
#     train_and_predict(X_train_all, y_train_all, X_test)
#   File "run.py", line 76, in train_and_predict
#     y_pred, y_valid_pred, model = classifier.train_and_predict(X_train, X_valid, y_train, y_valid, X_test, model_params)
#   File "/content/drive/MyDrive/git/kaggle-inclass-mnesframingham/models/neuralnet.py", line 126, in train_and_predict
#     train_dataset = MoADataset(X_train, y_train)
# NameError: name 'MoADataset' is not defined
